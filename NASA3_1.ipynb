# %%
import requests
import pandas as pd
import os

# Substitua 'SUA_CHAVE_DE_API_AQUI' pela sua chave de API da NASA
api_key = 'SnqqEUM5USSbhY2FrRtSdRNdkH32aCwDsyRwut4q'


def obter_dados_api(url):
    # Fazendo a solicitação GET para a API
    response = requests.get(url)

    # Verificando se a solicitação foi bem-sucedida
    if response.status_code == 200:
        # Convertendo a resposta para formato JSON
        data = response.json()
        # Retornando os dados
        return data
    else:
        print("Erro ao acessar a API")

# URL da API para coletar informações dos ROVERS
url = f"https://api.nasa.gov/mars-photos/api/v1/rovers/Perseverance/photos?earth_date=2024-10-27&api_key={api_key}"

print(url)
# Obtendo os dados da API
dados = obter_dados_api(url)

#exibindo os dados brutos
dados
# Out:
# https://api.nasa.gov/mars-photos/api/v1/rovers/Perseverance/photos?earth_date=2024-10-27&api_key=SnqqEUM5USSbhY2FrRtSdRNdkH32aCwDsyRwut4q
# {'photos': [{'id': 1274816,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337814_510ECM_N0611928NCAM00502_01_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274817,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337814_510ECM_N0611928NCAM00502_02_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274818,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337856_770ECM_N0611928NCAM00502_01_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274819,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337856_770ECM_N0611928NCAM00502_02_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274820,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337898_770ECM_N0611928NCAM00502_01_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274821,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337898_770ECM_N0611928NCAM00502_02_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274822,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783338028_770ECM_N0611928NCAM00502_01_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274823,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783338109_770ECM_N0611928NCAM00502_02_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274833,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783338028_770ECM_N0611928NCAM00502_02_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274834,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783338109_770ECM_N0611928NCAM00502_01_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274846,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337975_476ECM_N0611928NCAM00502_01_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274847,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLR_1311_0783337975_476ECM_N0611928NCAM00502_02_1I6J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274926,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLF_1311_0783336430_847ECM_N0611928NCAM03311_04_195J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274927,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLF_1311_0783336942_145ECM_N0611928NCAM02311_01_195J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274928,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLF_1311_0783337090_176ECM_N0611928NCAM02311_01_195J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274929,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337263_007ECM_N0611928SCAM04311_00_1LLJ02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274930,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337573_755ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274931,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337590_722ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274932,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337602_800ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274933,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337615_755ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274934,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337619_800ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274935,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337624_740ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274936,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337628_816ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274937,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337632_941ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274938,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLG_1311_0783337647_112ECM_N0611928NCAM00529_00_2I4J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274940,
#    'sol': 1311,
#    'camera': {'id': 38,
#     'name': 'NAVCAM_LEFT',
#     'rover_id': 8,
#     'full_name': 'Navigation Camera - Left'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/ncam/NLF_1311_0783336147_425ECM_N0611928NCAM13311_01_195J02_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
# ...
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274734,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRF_1311_0783321303_231EBY_N0611678SCAM01311_0070I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274735,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRF_1311_0783320595_276EBY_N0611678SCAM01311_0040I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274738,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRE_1311_0783324365_232ECM_N0611678SCAM02311_0100I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274739,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRE_1311_0783322528_027ECM_N0611678SCAM02311_0010I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274740,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRE_1311_0783322177_347ECM_N0611678SCAM01311_0100I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274741,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRE_1311_0783321303_231ECM_N0611678SCAM01311_0070I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274742,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRE_1311_0783320595_276ECM_N0611678SCAM01311_0040I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}},
#   {'id': 1274743,
#    'sol': 1311,
#    'camera': {'id': 48,
#     'name': 'SUPERCAM_RMI',
#     'rover_id': 8,
#     'full_name': 'SuperCam Remote Micro Imager'},
#    'img_src': 'https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/01311/ids/edr/browse/scam/LRE_1311_0783319874_387ECM_N0611678SCAM01311_0010I6J01_1200.jpg',
#    'earth_date': '2024-10-27',
#    'rover': {'id': 8,
#     'name': 'Perseverance',
#     'landing_date': '2021-02-18',
#     'launch_date': '2020-07-30',
#     'status': 'active',
#     'max_sol': 1311,
#     'max_date': '2024-10-27',
#     'total_photos': 245723,
#     'cameras': [{'name': 'EDL_RUCAM', 'full_name': 'Rover Up-Look Camera'},
#      {'name': 'EDL_DDCAM', 'full_name': 'Descent Stage Down-Look Camera'},
#      {'name': 'EDL_PUCAM1', 'full_name': 'Parachute Up-Look Camera A'},
#      {'name': 'EDL_PUCAM2', 'full_name': 'Parachute Up-Look Camera B'},
#      {'name': 'NAVCAM_LEFT', 'full_name': 'Navigation Camera - Left'},
#      {'name': 'NAVCAM_RIGHT', 'full_name': 'Navigation Camera - Right'},
#      {'name': 'MCZ_RIGHT', 'full_name': 'Mast Camera Zoom - Right'},
#      {'name': 'MCZ_LEFT', 'full_name': 'Mast Camera Zoom - Left'},
#      {'name': 'FRONT_HAZCAM_LEFT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Left'},
#      {'name': 'FRONT_HAZCAM_RIGHT_A',
#       'full_name': 'Front Hazard Avoidance Camera - Right'},
#      {'name': 'REAR_HAZCAM_LEFT',
#       'full_name': 'Rear Hazard Avoidance Camera - Left'},
#      {'name': 'REAR_HAZCAM_RIGHT',
#       'full_name': 'Rear Hazard Avoidance Camera - Right'},
#      {'name': 'EDL_RDCAM', 'full_name': 'Rover Down-Look Camera'},
#      {'name': 'SKYCAM', 'full_name': 'MEDA Skycam'},
#      {'name': 'SHERLOC_WATSON', 'full_name': 'SHERLOC WATSON Camera'},
#      {'name': 'SUPERCAM_RMI', 'full_name': 'SuperCam Remote Micro Imager'},
#      {'name': 'LCAM', 'full_name': 'Lander Vision System Camera'}]}}]}

# %%
# Inicializando uma lista para armazenar os dados do rover
photo_data = []
for photo in dados['photos']:
    photo_data.append({
        'photo_id': photo['id'],
        'sol': photo['sol'],
        'camera_id': photo['camera']['id'],
        'camera_name': photo['camera']['name'],
        'camera_full_name': photo['camera']['full_name'],
        'img_src': photo['img_src'],
        'earth_date': photo['earth_date'],
        'rover_id': photo['rover']['id'],
        'rover_name': photo['rover']['name'],
        'rover_landing_date': photo['rover']['landing_date'],
        'rover_launch_date': photo['rover']['launch_date'],
        'rover_status': photo['rover']['status'],
    })

# Criando o DataFrame a partir da lista de dicionários
df = pd.DataFrame(photo_data)

# Exibindo o DataFrame
df

# Salvar o DataFrame em formato CSV
df.to_csv('nasa_photos.csv', index=False)

# Criar o diretório para salvar as fotos
directory = 'Perseverance'
os.makedirs(directory, exist_ok=True)


# Baixar cada uma das fotos e salvar no diretório
for photo in photo_data:
    img_url = photo['img_src']
    img_name = os.path.join(directory, f"{photo['photo_id']}.jpg")
    response = requests.get(img_url)
    if response.status_code == 200:
        with open(img_name, 'wb') as img_file:
            img_file.write(response.content)
            print(f"baixei a imagem: {img_name}")
# Out:
# baixei a imagem: Perseverance\1274816.jpg
# baixei a imagem: Perseverance\1274817.jpg
# baixei a imagem: Perseverance\1274818.jpg
# baixei a imagem: Perseverance\1274819.jpg
# baixei a imagem: Perseverance\1274820.jpg
# baixei a imagem: Perseverance\1274821.jpg
# baixei a imagem: Perseverance\1274822.jpg
# baixei a imagem: Perseverance\1274823.jpg
# baixei a imagem: Perseverance\1274833.jpg
# baixei a imagem: Perseverance\1274834.jpg
# baixei a imagem: Perseverance\1274846.jpg
